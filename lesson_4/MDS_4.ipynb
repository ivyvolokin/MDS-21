# %% [markdown]
# Домашнее задание "Математический анализ. Производная".
# Уровень 0:
# Посчитайте значение первой и второй производной функции:
#  $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
from scipy.misc import derivative
from math import *
#значение первой производной
def f(x):
    return x ** 5 + 4 * sin(2 * x) + cos(3 * x + 3)
derivative(f, 1.0, dx=1e-6)
# Out:
# 2.509071801881646

# %%
#значение второй производной
def f(x):
    return x ** 5 + 4 * sin(2 * x) + cos(3 * x + 3)
derivative(f, 1.0, dx=1e-6, n=2)
# Out:
# -3.19033688356285

# %% [markdown]
# Уровень 1:
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import numpy as np
import matplotlib.pyplot as plt

def g(x):
    return sin( 5 * (2 * x + 1))
x = np.linspace(-5, 5)

#значение первой производной

for xx in x:
    g1 = derivative(g, xx, dx=1e-6, n=1)


#значение второй производной

for XX in x:
    g2 = derivative(g, xx, dx=1e-6, n=2)

# %%
plt.plot(x, g1x, label='первая производная')
plt.plot(x, g2x, label='вторая производная')
# plt.legend()
plt.show()
